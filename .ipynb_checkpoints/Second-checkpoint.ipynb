# %%
import numpy as np 
import pandas as pd

# %%
nepal_tourism_data=pd.read_csv('1.tourist-arrivals-and-average-length-of-stay-in-nepal-19642024.csv')
nepal_tourism_data.head()
# Out:
#    Year Value         Metric     Type
# 0  1964  30.9  Annual_Growth   Number
# 1  1964     -       Avg_Stay   Number
# 2  1964  8435         By_Air   Number
# 3  1964  88.5         By_Air  Percent
# 4  1964  1091        By_Land   Number

# %%
nepal_tourism_data.shape
# Out:
# (366, 4)
